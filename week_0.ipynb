# %%
age = 18
if age >= 18:
  print("eligible")
else:
  print("not eligible")
# Out:
# eligible

# %%
a = 3
b = 4
c = 4
if a + b > c:
  if  b + c > a:
    if a + c > b:
      print("a triangle")
    else:
      p
  if a != b != c:
    print("scalene")
elif a == b != c:
   print("isosceles")
elif a == c != b:
   print("isosceles")
elif b == c != a:
      print("isosceles")
else:
  print("equilateral")
# Out:
# a triangle

# %%
a = 2
b = 2
c = 2
if a != b:
  if b != c:
    if a !=c:
      print("scalene")
    elif a == b:
      print("isosceles")
    elif  b == c:
      print("isosceles")
    elif a == c:
      print("isosceles")
else:
  print("equilateral")
# Out:
# equilateral

# %%
a = 3
b = 5
c = 9
if a + b > c:
  if  b + c > a:
    if a + c > b:
      print("a triangle")
      if a == b == c:
            print("equilateral")
      elif a == b:
            print("isosceles")
      elif b == c:
            print("isosceles")
      elif a == c:
            print("isosceles")
      else:
            print("scalene")
else:
      print("not a triangle")
# Out:
# not a triangle

# %%
win = 4
lose = 2
draw = 1
totalpoints = (win * 3) + (lose * 0) + (draw * 1)
print(totalpoints)
# Out:
# 13

# %% [markdown]
# #dry concept in programming
# #resove the negativity first

# %%
#Given 2 angles in a triangle, find the missing angle and print the type of triangle.
a = 60
b = 60
c = 180 - a - b
print('c:', c)
if a == b == c:
    print('equilateral')
elif a != b != c:
    print()
# Out:
# c: 60
# equilateral

# %%
# Given a list of integers, find the average of all the numbers and say whether the result is whole number or not.
x = 7
y = 2
z = 5
r = 89
avg = (x + y + z + r) / 4
print(avg)
if (x + y + z + r) % 4 == 0:
    print('whole number')
else:
    print('not a whole number')
# Out:
# 25.75
# not a whole number

# %%
# a program to find the volume of sphere.
r = 3
vol = 1.333 * 3.141 * (r ** 3)
print('vol:',vol)
# Out:
# vol: 113.047731

# %%
def compoundinterset(p, ty, ar, cp):
    ratedec = ar / 100;
    amount = p * (1 + ratedec / cp) ** (cp * ty)
    return round(amount,2)
    p = 10000
    ty = 10
    ar = 6
    cp = 12
    totalamount =  compoundinterest(p, ty, ar, cp)
    print(totalamount)

# %%
value = "17654"
print(value[::3])
print(value == value[:: 1])
# Out:
# 15
# True

# %%
lst = [1, 2, 4]

# %%
product = 1
total = 0
for i in lst:
    total += i
    product *= i
print(total > product)
# Out:
# False

# %%
principal = 10000
termyears = 10
annualrate = 6
compoundingperiod = 12
decrate = annualrate / 100
print(principal * (1 + decrate / compoundingperiod)**(compoundingperiod*termyears))
# Out:
# 18193.9673403229

# %%
len('123')
# Out:
# 3
